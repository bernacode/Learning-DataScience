# %%
import numpy as np

arr = np.arange(0,6)
print(arr)
# Out:
# [0 1 2 3 4 5]

# %%
binario = np.array([bin(n)[2:] for n in arr])
print(binario)
# Out:
# ['0' '1' '10' '11' '100' '101']

# %%
def tranformar_binario(decimal):
    if decimal == 0:
        return "0"
    
    binario = ""

    while decimal > 0:
        resto = decimal % 2
        binario = str(resto) + binario
        decimal = decimal // 2
    
    return binario

# %%
binario = np.array([tranformar_binario(n) for n in arr])
print(binario)
# Out:
# ['0' '1' '10' '11' '100' '101']
