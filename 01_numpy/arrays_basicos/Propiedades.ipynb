# %%
import numpy as np  

a = np.array([[1,2,3],[4,5,6]])

print("Forma: ", a.shape) 
print("Dimensiones: ", a.ndim)
print("Tamano total:", a.size)
print("Tipo de datos: ", a.dtype)
# Out:
# Forma:  (2, 3)
# Dimensiones:  2
# Tamano total: 6
# Tipo de datos:  int64
