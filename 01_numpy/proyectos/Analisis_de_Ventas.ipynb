# %%
import numpy as np

# Días
dias = np.array(["Lun", "Mar", "Mié", "Jue", "Vie", "Sáb", "Dom", "Lun", "Mar", "Mié"])

# Productos vendidos por día
productos_vendidos = np.array([120, 135, 150, 160, 145, 180, 200, 175, 190, 210])

# Precio promedio por producto ($)
precio_promedio = np.array([15.5, 15.0, 14.8, 15.2, 15.3, 15.1, 15.7, 15.6, 15.9, 16.0])

# Coste promedio por producto ($)
coste_promedio = np.array([10.2, 10.0, 9.8, 10.1, 10.3, 10.2, 10.4, 10.1, 10.3, 10.5])

# %% [markdown]
# 1. Calcular ingresos totales por dia

# %%
ingresos = productos_vendidos * precio_promedio
print(ingresos)
# Out:
# [1860.  2025.  2220.  2432.  2218.5 2718.  3140.  2730.  3021.  3360. ]

# %% [markdown]
# 2. Calcular beneficio neto diario

# %%
beneficio = (precio_promedio-coste_promedio)*productos_vendidos
print(beneficio.sum())
# Out:
# 8725.5

# %% [markdown]
# 3. Obtener estadisticas basicas

# %%
prom = np.mean(productos_vendidos)
maximo = np.max(ingresos)
minimo = np.min(ingresos)

pmax = np.argmax(ingresos)

print("Promedio de vendtas: ", round(prom))
print("Maximo: ", maximo)
print("Minimo: ", minimo)
print("Dia con mayor beneficio: ", dias[pmax])
# Out:
# Promedio de vendtas:  166
# Maximo:  3360.0
# Minimo:  1860.0
# Dia con mayor beneficio:  Mié

# %% [markdown]
# 4. Filtrar los dias con ventas superiores al promedio

# %%
positions = np.where(productos_vendidos > prom)
print("Dias con ventas superiores al promedio")
print(dias[positions])
# Out:
# Dias con ventas superiores al promedio
# ['Sáb' 'Dom' 'Lun' 'Mar' 'Mié']

# %% [markdown]
# 5. Simular un aumento del 10% en el precio y recalcular el beneficio total.

# %%
beneficio = np.sum((precio_promedio * 1.10 - coste_promedio) * productos_vendidos)
print(round(beneficio,2))
# Out:
# 11297.95

# %% [markdown]
# 6. Crear una matriz combinada con las tres columnas

# %%
matriz = np.column_stack((dias,productos_vendidos,precio_promedio,coste_promedio))
print(matriz)
# Out:
# [['Lun' '120' '15.5' '10.2']
#  ['Mar' '135' '15.0' '10.0']
#  ['Mié' '150' '14.8' '9.8']
#  ['Jue' '160' '15.2' '10.1']
#  ['Vie' '145' '15.3' '10.3']
#  ['Sáb' '180' '15.1' '10.2']
#  ['Dom' '200' '15.7' '10.4']
#  ['Lun' '175' '15.6' '10.1']
#  ['Mar' '190' '15.9' '10.3']
#  ['Mié' '210' '16.0' '10.5']]
