# %%
import numpy as np

# Crear un array basico
a = np.array([1,2,3,4,5])

print("Array: ", a)
print("Shape: ", a.shape)
print("Tipo de datos:",a.dtype)
# Out:
# Array:  [1 2 3 4 5]
# Shape:  (5,)
# Tipo de datos: int64
