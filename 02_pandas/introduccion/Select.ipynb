# %%
import pandas as pd

# %%
students = pd.read_csv("../../datasets/StudentsPerformance.csv")

# %%
students.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
mathScore = students["math score"]

# %%
mathScore.head()
# Out:
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# Name: math score, dtype: int64

# %%
type(students["math score"])
# Out:
# pandas.core.series.Series

# %%
students["math score"].shape
# Out:
# (1000,)

# %%
students
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
mathScore_gender = students[["gender","math score","reading score","writing score"]]

# %%
mathScore_gender.head()
# Out:
#    gender  math score  reading score  writing score
# 0  female          72             72             74
# 1  female          69             90             88
# 2  female          90             95             93
# 3    male          47             57             44
# 4    male          76             78             75

# %%
type(students[["gender","math score"]])
# Out:
# pandas.core.frame.DataFrame

# %%
students[["gender","math score"]].shape
# Out:
# (1000, 2)

# %%
MathScore_50 = students[students["math score"] > 50]

# %%
MathScore_50.head()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 4    male        group C                some college  standard
# 5  female        group B          associate's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 4                    none          76             78             75
# 5                    none          71             83             78

# %%
students["math score"] > 50
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: math score, Length: 1000, dtype: bool

# %%
MathScore_50.shape
# Out:
# (850, 8)

# %%
students[students["math score"].isin([50,60])]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 14   female        group A             master's degree      standard
# 37   female        group D            some high school  free/reduced
# 44   female        group E          associate's degree  free/reduced
# 67   female        group C                some college      standard
# 82     male        group A                some college  free/reduced
# 103    male        group B                 high school      standard
# 157    male        group B                some college  free/reduced
# 182  female        group E                 high school      standard
# 213    male        group C          associate's degree  free/reduced
# 252  female        group B            some high school      standard
# 396  female        group B                 high school  free/reduced
# 399    male        group D            some high school      standard
# 435    male        group C                some college  free/reduced
# ...

# %%
students[(students["math score"] >= 50) & (students["math score"] <= 55)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 14   female        group A             master's degree      standard
# 19   female        group C          associate's degree  free/reduced
# 37   female        group D            some high school  free/reduced
# 40     male        group C          associate's degree  free/reduced
# 42   female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 945  female        group C          associate's degree      standard
# 972  female        group A                 high school  free/reduced
# 974  female        group A                some college      standard
# 978    male        group D                 high school      standard
# 992  female        group D          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# True si tiene valor

# %%
students[students["reading score"].notna()]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# True si esta vacio

# %%
students[students["reading score"].isna()]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score]
# Index: []

# %%
students[students["test preparation course"] == "completed"]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 6    female        group B                some college      standard
# 8      male        group D                 high school  free/reduced
# 13     male        group A                some college      standard
# 18     male        group C             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students["test preparation course"] == "completed"
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999    False
# Name: test preparation course, Length: 1000, dtype: bool

# %%
students[(students["math score"] <= 50) & (students["race/ethnicity"] == "group A")]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 14   female        group A             master's degree      standard
# 61     male        group A            some high school  free/reduced
# 72   female        group A          associate's degree  free/reduced
# 82     male        group A                some college  free/reduced
# 250    male        group A            some high school      standard
# 296    male        group A            some high school      standard
# 327    male        group A                some college  free/reduced
# 365    male        group A           bachelor's degree  free/reduced
# 368  female        group A            some high school  free/reduced
# 384  female        group A            some high school  free/reduced
# 395    male        group A                 high school  free/reduced
# 402  female        group A                some college  free/reduced
# ...

# %%
groupA = students[students["race/ethnicity"] == "group A"]
groupA.head()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 13    male        group A                some college      standard
# 14  female        group A             master's degree      standard
# 25    male        group A             master's degree  free/reduced
# 46  female        group A          associate's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 3                     none          47             57             44
# 13               completed          78             72             70
# 14                    none          50             53             58
# 25                    none          73             74             72
# 46               completed          55             65             62

# %%
filtro = students[students["test preparation course"] == "none"]
filtro.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# 5                    none          71             83             78

# %%
filtro = students[(students["race/ethnicity"] == "group A") & (students["test preparation course"] == "none")]
filtro.head()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 14  female        group A             master's degree      standard
# 25    male        group A             master's degree  free/reduced
# 61    male        group A            some high school  free/reduced
# 62    male        group A          associate's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 3                     none          47             57             44
# 14                    none          50             53             58
# 25                    none          73             74             72
# 61                    none          39             39             34
# 62                    none          62             61             55

# %%
filtro = students.loc[students["math score"] < 30, "race/ethnicity"]
filtro.head()
# Out:
# 17     group B
# 59     group C
# 91     group C
# 145    group C
# 327    group A
# Name: race/ethnicity, dtype: object

# %%
filtro = students.iloc[9:25, 5:8]
filtro
# Out:
#     math score  reading score  writing score
# 9           38             60             50
# 10          58             54             52
# 11          40             52             43
# 12          65             81             73
# 13          78             72             70
# 14          50             53             58
# 15          69             75             78
# 16          88             89             86
# 17          18             32             28
# 18          46             42             46
# 19          54             58             61
# 20          66             69             63
# 21          65             75             70
# 22          44             54             53
# 23          69             73             73
# 24          74             71             80
