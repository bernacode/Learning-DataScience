# %%
import numpy as np

U = np.array([1,2,3,4,5,6,7])
A = np.array([1,3,5,7])
B = np.array([2,3,4,5])

C = np.intersect1d(A,B)
print(C)
# Out:
# [3 5]

# %% [markdown]
# La interseccion incluye solo los elementos que son comunes a ambos conjuntos A y B.
