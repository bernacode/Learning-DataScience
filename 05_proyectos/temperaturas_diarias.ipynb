# %%
import numpy as np

dias = np.arange(1,31)
temperaturas = np.random.randint(10,35,30)
print(dias)
print(temperaturas)
# Out:
# [[ 1 15]
#  [ 2 10]
#  [ 3 14]
#  [ 4 26]
#  [ 5 16]
#  [ 6 10]
#  [ 7 14]
#  [ 8 26]
#  [ 9 31]
#  [10 23]
#  [11 30]
#  [12 33]
#  [13 25]
#  [14 28]
#  [15 30]
#  [16 15]
#  [17 10]
#  [18 11]
#  [19 34]
#  [20 10]
#  [21 23]
#  [22 32]
#  [23 12]
#  [24 25]
#  [25 15]
#  [26 18]
#  [27 25]
#  [28 16]
#  [29 17]
#  [30 14]]

# %%
temperatura_media = np.mean(temperaturas)
print("Temperatura media: ", round(temperatura_media,2), "C")

indices = np.where(temperaturas > 30)

dias_superaron = dias[indices]
numeros_de_dias = len(dias_superaron)
print("Dias que tuvieron una temperatura > 30 C: ", dias_superaron, numeros_de_dias)

temperatura_maxima = temperaturas.max()
print("Temperatura maxima: ",temperatura_maxima)

indice_maximo = np.argmax(temperaturas)
print("Dia con la mayor temperatura: ", dias[indice_maximo])
# Out:
# Temperatura media:  20.27 C
# Dias que tuvieron una temperatura > 30 C:  [ 9 12 19 22] 4
# Temperatura maxima:  34
# Dia con la mayor temperatura:  19

# %%
# Con otros datos:

datos = np.array([24.5, 29.3, 31.1, 18.7, 26.2, 30.5, 33.8, 27.9, 22.4, 20.1,
 28.7, 34.2, 32.0, 19.8, 25.9, 21.4, 29.8, 30.9, 33.1, 17.3,
 27.2, 26.8, 19.5, 23.0, 28.4, 31.7, 32.9, 30.2, 29.0, 34.8])

media = np.mean(datos)
dias = np.sum(datos > 30)
max_temp = np.max(datos)
dia_max = np.argmax(datos) + 1

print("Media: ", media, " C")
print("Numero de dias con la temperatura mayores a 30 C: ", dias)
print("Temperatura maxima: ", max_temp)
print("Dia con la mayor temperatura: ", dia_max)
# Out:
# Media:  27.37  C
# Numero de dias con la temperatura mayores a 30 C:  11
# Temperatura maxima:  34.8
# Dia con la mayor temperatura:  30
